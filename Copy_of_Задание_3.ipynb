# %% [markdown]
# <a href="https://colab.research.google.com/github/AriorhBiel/12343/blob/main/Copy_of_%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 3

# %% [markdown]
# ##Обработка пропущенных значений

# %% [markdown]
# Обработайте пропущенные значения:
#
#
# * Удалите пропущенные значения
# * Заполните при помощи медианы, среднего для числовых значений
# * Заполните при помощи моды для категориальных значений
# * Интерполируйте
# Выведите статистку после каждого метода и объясните

# %%
# !pip install scikit-learn

# %%
import pandas as pd

df = pd.read_csv("Global YouTube Statistics.csv", encoding="ISO-8859–1")
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
#Удаление
df_drop = df.dropna()

df_drop.describe()
# Out:
#              rank   subscribers   video views        uploads  \
# count  554.000000  5.540000e+02  5.540000e+02     554.000000
# mean   463.828520  2.462401e+07  1.310608e+10   14758.036101
# std    289.929893  1.950924e+07  1.729334e+10   44248.913413
# min      1.000000  1.230000e+07  2.634000e+03       1.000000
# 25%    206.500000  1.490000e+07  5.102920e+09     436.500000
# 50%    448.500000  1.880000e+07  9.040989e+09    1278.000000
# 75%    702.750000  2.670000e+07  1.540470e+10    4142.500000
# max    995.000000  2.450000e+08  2.280000e+11  301308.000000
#
#        video_views_rank  country_rank  channel_type_rank  \
# count      5.540000e+02    554.000000         554.000000
# mean       1.297121e+05    180.850181         238.034296
# std        6.815954e+05    732.093496         937.109139
# min        1.000000e+00      1.000000           1.000000
# 25%        2.222500e+02     10.000000          19.000000
# 50%        5.695000e+02     40.500000          48.000000
# ...

# %%
#Заполнение при помощи медианы
df_median = df.fillna(df.median())

df_median.describe()
# Out:
# <ipython-input-7-60bbc7ecd736>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_median = df.fillna(df.median())
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.950000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.536928e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362209e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.240000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.579000e+03
# ...

# %%
#Заполнение при помощи среднего
df_mean = df.fillna(df.mean())

df_mean.describe()
# Out:
# <ipython-input-8-6fbc5020ae8f>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mean = df.fillna(df.mean())
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.950000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362097e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.240000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.180000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.617500e+03
# ...

# %%
#Заполнение при помощи моды
df_mode = df.fillna(df.mode())

df_mode.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
#Заполнение при помощи интерполяции
df_interpol = df.interpolate()

df_interpol.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.950000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.536929e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362209e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.240000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.180000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.579000e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    995.000000         995.000000                      9.950000e+02
# mean     383.139196         750.360302                      1.741601e+08
# ...

# %% [markdown]
# **Объясните**
#
# Примерно половина значений имеют пустые значения, наполнение их средними значениями сильно повлияет на модель
#
# В целом, данные методы заполнения дают схожую инфрмационную картину

# %% [markdown]
# ##Поиск выбросов и аномалий

# %% [markdown]
# **Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса**
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %%
#Методом среднего

# %%
#При помощи межквартильного размаха

# %%
#Статистика и объяснение

# %% [markdown]
# **Объяснения**

# %% [markdown]
# ##Дубликаты

# %% [markdown]
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли

# %%
#Удаление дублей

# %% [markdown]
# ## Преобразование признаков

# %% [markdown]
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Creating instances
min_max_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of OneHotEncoder
encoder = OneHotEncoder()

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать расчет корреляции Спирмана

# %%
#Функция по расчету тут

# %%
#Пример использования тут и объяснение принципа работы

# %% [markdown]
# ###Пример реализации

# %%
import pandas as pd
import numpy as np


def corr_pearson(column_1, column_2):
  cov = np.cov(column_1, column_2)
  return cov/(column_1.std() * column_2.std())

# %%
data = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес': [65, 50, 75, 55, 70]
}
df = pd.DataFrame(data)
df
# Out:
#    Рост  Вес
# 0   170   65
# 1   155   50
# 2   180   75
# 3   162   55
# 4   175   70

# %%
corr_pearson(df["Рост"], df["Вес"])
# Out:
# array([[0.96593129, 0.99674864],
#        [0.99674864, 1.03527033]])
